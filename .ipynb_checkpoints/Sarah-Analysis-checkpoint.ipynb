# %% [markdown]
# # Named Entity Recognition Analysis

# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import spacy
from spacy import displacy
from spacymoji import Emoji

# import data and read to df
csv = "../Output/all_data.csv"
df = pd.read_csv(csv, low_memory=False)

df.head()
# Out:
#              tweet_id  Compound_Score  Positive_Score  Negative_Score  \
# 0  914580356430536707          0.0000           0.000           0.000
# 1  914621840496189440          0.0000           0.000           0.000
# 2  914623490375979008         -0.1531           0.126           0.198
# 3  914639143690555392          0.0000           0.000           0.000
# 4  914312219952861184          0.6399           0.413           0.000
#
#    Neutral_Score  external_author_id  author  \
# 0          1.000  906000000000000000  10_GOP
# 1          1.000  906000000000000000  10_GOP
# 2          0.676  906000000000000000  10_GOP
# 3          1.000  906000000000000000  10_GOP
# 4          0.587  906000000000000000  10_GOP
#
#                                              content   region language  \
# 0  "We have a sitting Democrat US Senator on tria...  Unknown  English
# 1  Marshawn Lynch arrives to game in anti-Trump s...  Unknown  English
# 2  Daughter of fallen Navy Sailor delivers powerf...  Unknown  English
# 3  JUST IN: President Trump dedicates Presidents ...  Unknown  English
# 4  19,000 RESPECTING our National Anthem! #StandF...  Unknown  English
#
#           publish_date  following  followers  updates post_type account_type  \
# 0  2017-10-01 19:58:00       1052       9636      253       NaN        Right
# 1  2017-10-01 22:43:00       1054       9637      254       NaN        Right
# 2  2017-10-01 22:50:00       1054       9637      255   RETWEET        Right
# 3  2017-10-01 23:52:00       1062       9642      256       NaN        Right
# 4  2017-10-01 02:13:00       1050       9645      246   RETWEET        Right
#
#    retweet account_category  new_june_2018     alt_external_id
# 0        0       RightTroll              0  905874659358453760
# 1        0       RightTroll              0  905874659358453760
# 2        1       RightTroll              0  905874659358453760
# 3        0       RightTroll              0  905874659358453760
# 4        1       RightTroll              0  905874659358453760

# %%
# group the dataframe by account because I'm curious

account_df = df[["author", "Compound_Score", "Positive_Score", "Negative_Score", "Neutral_Score", "updates", "following", "followers"]]
account_type_ref = df[["author", "account_type"]].drop_duplicates()
account_df = account_df.groupby(df["author"]).mean()
account_df = account_df.merge(account_type_ref, left_index=True, right_on='author').set_index('author')

account_df.head(5)
# Out:
#               Compound_Score  Positive_Score  Negative_Score  Neutral_Score  \
# author
# 10_GOP              0.078718        0.131511        0.089804       0.778685
# 1D_NICOLE_          0.177359        0.193545        0.069000       0.737455
# 1ERIK_LEE          -0.549850        0.000000        0.214000       0.786000
# 2NDHALFONION        0.439200        0.186000        0.000000       0.814000
# 4EVER_SUSAN         0.042470        0.133794        0.104810       0.761413
#
#                  updates   following    followers account_type
# author
# 10_GOP        176.500000  985.018817  7044.306452        Right
# 1D_NICOLE_    373.500000   58.500000    51.477273         Koch
# 1ERIK_LEE     333.000000  239.000000    74.000000        Right
# 2NDHALFONION   10.000000   22.000000     1.000000        Right
# 4EVER_SUSAN    37.047619   75.650794    57.777778        Right

# %%
# import and create a default dictionary to store words as it finds them from function below
from collections import defaultdict
word_counts = defaultdict(int) #template for simpler function code

# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# make separate dfs for left and right trolls
right_troll_df = df[df["account_category"] == "RightTroll"]
left_troll_df = df[df["account_category"] == "LeftTroll"]

# function to run NER 
def getEntities(tweet):
    output = nlp(tweet)
    ents = output.ents
    return_list = []
    for ent in ents:
        return_list.append(ent.text.lower())
        word_counts[ent.text.lower()] += 1
    return return_list

# run on a random sample of Left and Right Trolls
Right = right_troll_df['content'].sample(n=25000).apply(getEntities)
Right_Counts = word_counts #dict for right measurements
del word_counts 
word_counts = defaultdict(int)
Left = left_troll_df['content'].sample(n=25000).apply(getEntities)
Left_Counts = word_counts #dict for left measurements
del word_counts

# %%
#get the value from the key-value dictionary
def getSecond(x):
    return x[1]

#Get Top Entities from the Right Trolls df and sort by most instances to least
top = 50
sorted_entities = sorted(Right_Counts.items(), key=getSecond, reverse=True)
for ent in sorted_entities[0:top]:
    print("{} - {}".format(ent[1], ent[0]))
# Out:
# 1116 - rt
# 801 -
# 757 - #
# 652 - obama
# 594 - hillary
# 507 - trump
# 421 - maga
# 402 - america
# 382 - cnn
# 291 - us
# 263 - one
# 241 - american
# 239 - gop
# 238 - russia
# 218 - democrats
# 205 - clinton
# 203 - u.s.
# 201 - today
# 194 - fbi
# 187 - 🇺
# 184 - 2
# 183 - americans
# 182 - donald trump
# 180 - first
# 177 - fakenews
# 167 - democrat
# 158 - muslim
# 157 - congress
# 157 - dems
# 157 - hillary clinton
# 145 - lol
# 144 - pjnet
# 137 - antifa
# 133 - nfl
# 131 - 4
# 127 - iran
# 127 - dem
# 126 - north korea
# 126 - charlottesville
# 115 - dnc
# 115 - muslims
# 114 - two
# 112 - ️
# 108 - california
# 107 - republicans
# 105 - #mar
# 102 - msm
# 101 - texas
# 95 - islam
# 95 - israel

# %%
#Get Top Entities from the Left Trolls df and sort by most instances to least
top = 50
sorted_entities = sorted(Left_Counts.items(), key=getSecond, reverse=True)
for ent in sorted_entities[0:top]:
    print("{} - {}".format(ent[1], ent[0]))
# Out:
# 733 -
# 621 - #
# 481 - blacklivesmatter
# 326 - trump
# 314 - today
# 299 - one
# 269 - first
# 231 - 2
# 216 - america
# 215 - us
# 187 - rt
# 166 - ️
# 158 - obama
# 137 - chicago
# 136 - 1
# 135 - 4
# 128 - 2016
# 122 - donald trump
# 122 - gop
# 117 - 3
# 115 - @youtube
# 112 - russia
# 107 - 5
# 105 - tonight
# 105 - trump's
# 105 - american
# 103 - two
# 95 - black
# 90 - 2017
# 90 - u.s.
# 82 - 10
# 75 - americans
# 74 - blm
# 72 - clinton
# 68 - staywoke
# 64 - hillary
# 64 - republicans
# 64 - blackhistorymonth
# 63 - dagr8fm
# 60 - 6
# 60 - texas
# 60 - god
# 58 - @realdonaldtrump
# 57 - tomorrow
# 57 - muslim
# 56 - rapstationradio
# 56 - baltimore
# 55 - \|
# 55 - fbi
# 53 - @josephjett

# %% [markdown]
# # Most common words
# Here are some of the most common words between left and right trolls. The search_terms list below will include different spellings of these words or words that are very closely associated, like if "trump" was a most used word, "donald" would mean the same thing and be added to this list. I will search all of these words with a function to find content that "contains" certain words so that I can see a comprehensive overview of how many tweets mentioned the subjects, and not just the most used word of the subjects below.
#
# 1. Trump
# 2. BlackLivesMatter
# 3. Hillary
# 4. Wall
# 5. Obama
# 6. America
# 7. Republican
# 8. Democrat
# 9. MAGA
# 10. Islam
# 11. Fake news
# 12. Russia

# %%
# make a df for the search terms so you can store the frequency that they appear in a search 
    # and the avg sentiment score that the right and the left associates with them
common_words_scored = ["Subject", "Right_Frequency", "Left_Frequency", "Right_Sentiment", "Left_Sentiment"]

# %%
search_terms = {"Trump": ["Trump", "Donald", "DJT", "trump's", "realdonaldtrump"],
                "BlackLivesMatter": ["BlackLivesMatter", "blacklives", "black", "blm", "get woke", "blackhistorymonth", "african american"],
                "Hillary": ["Hillary", "Clinton"],
                "Wall": ["Wall", "build", "border"],
                "Obama": ["Obama", "obamacare", "barack"],
                "America": ["America", "USA", "united states", "merca", "u.s.", "American"],
                "Republican": ["Republican", "gop", "conservative", "right wing"],
                "Democrat": ["Democrat", "dem", "libs", "liberal", "left wing", "dnc"],
                "Maga": ["Maga", "make america great again"],
                "Islam": ["Islam", "muslim", "iran", "iraq", "israel", "middle east","isis"],
                "Fakenews": ["Fake news","fakenews","fox","cnn","msnbc","WaPo","Washington Post","NYT","New York Times","HuffPost","Huffington","Yahoo"],
                "Russia": ["Russia"]
               }

# %%
final_df = defaultdict(list)
right_troll_df['content'] = right_troll_df['content'].str.lower()
left_troll_df['content'] = left_troll_df['content'].str.lower()

# functions to find the frequency of common words and their avg sentiment from left and right account

def calculateRightFrequency(termsList):
    related_rows = right_troll_df[right_troll_df['content'].str.contains("|".join(termsList))]
    return len(related_rows)

def calculateLeftFrequency(termsList):
    related_rows = left_troll_df[left_troll_df['content'].str.contains("|".join(termsList))]
    return len(related_rows)

def calculateRightSentiment(termsList):
    related_rows = right_troll_df[right_troll_df['content'].str.contains("|".join(termsList))]
    return pd.to_numeric(related_rows["Compound_Score"]).mean()

def calculateLeftSentiment(termsList):
    related_rows = left_troll_df[left_troll_df['content'].str.contains("|".join(termsList))]
    return pd.to_numeric(related_rows["Compound_Score"]).mean()

def calculateRightStdDev(termsList):
    related_rows = right_troll_df[right_troll_df['content'].str.contains("|".join(termsList))]
    return pd.to_numeric(related_rows["Compound_Score"]).std()

def calculateLeftStdDev(termsList):
    related_rows = left_troll_df[left_troll_df['content'].str.contains("|".join(termsList))]
    return pd.to_numeric(related_rows["Compound_Score"]).std()

def calculateRightUpdates(termsList):
    related_rows = right_troll_df[right_troll_df['content'].str.contains("|".join(termsList))]
    return pd.to_numeric(related_rows["updates"]).mean()

def calculateLeftUpdates(termsList):
    related_rows = left_troll_df[left_troll_df['content'].str.contains("|".join(termsList))]
    return pd.to_numeric(related_rows["updates"]).mean()

for term in search_terms:
    search_terms[term] = [ t.lower() for t in search_terms[term] ]
    final_df['Topic'].append(term)
    final_df["Right_Frequency"].append(calculateRightFrequency(search_terms[term]))
    final_df["Left_Frequency"].append(calculateLeftFrequency(search_terms[term]))
    final_df["Right_Sentiment"].append(calculateRightSentiment(search_terms[term]))
    final_df["Left_Sentiment"].append(calculateLeftSentiment(search_terms[term]))
    final_df["Right_Sentiment_Std"].append(calculateRightStdDev(search_terms[term]))
    final_df["Left_Sentiment_Std"].append(calculateRightStdDev(search_terms[term]))
    final_df["Right_Updates"].append(calculateRightUpdates(search_terms[term]))
    final_df["Left_Updates"].append(calculateLeftUpdates(search_terms[term]))

final_df = pd.DataFrame(final_df)
final_df.head(12)
# Out:
#                Topic  Right_Frequency  Left_Frequency  Right_Sentiment  \
# 0              Trump           139455           28178        -0.035907
# 1   BlackLivesMatter            14513           53130        -0.145995
# 2            Hillary            52230            5311        -0.085268
# 3               Wall            10403            3785        -0.049571
# 4              Obama            45185            5938        -0.107213
# 5            America           135688           56162        -0.041184
# 6         Republican            28177            6593        -0.034941
# 7           Democrat            59551            8762        -0.159778
# 8               Maga            18707            2317         0.045751
# 9              Islam            42693            6939        -0.186188
# 10          Fakenews            35193            7394        -0.123897
# 11            Russia            11948            3546        -0.163501
#
#     Left_Sentiment  Right_Sentiment_Std  Left_Sentiment_Std  Right_Updates  \
# 0        -0.069399             0.456759            0.456759   10070.070740
# 1        -0.018735             0.454990            0.454990    8034.139392
# 2        -0.013561             0.422539            0.422539    9004.150029
# 3         0.063941             0.430326            0.430326   12549.104681
# 4        -0.016021             0.434051            0.434051    7752.373819
# 5         0.004665             0.461271            0.461271   10244.696281
# 6        -0.055502             0.433535            0.433535    8166.365546
# 7        -0.040120             0.446818            0.446818    9717.473796
# 8         0.126126             0.453496            0.453496   18903.959641
# 9        -0.184455             0.447204            0.447204    6979.531492
# 10       -0.031851             0.431529            0.431529   15550.683261
# 11       -0.071404             0.420719            0.420719   13048.254017
#
#     Left_Updates
# 0    3576.116509
# 1    3078.636345
# 2    2584.819808
# 3    3792.928666
# 4    3443.387504
# 5    3618.212368
# 6    3034.659487
# 7    3416.699612
# 8    3899.510574
# 9    3090.720421
# 10   3521.203814
# 11   4725.677383

# %%
#find example tweets for presentation
list(right_troll_df[right_troll_df["content"].str.contains("blacklivesmatter")]["content"].head(50))
# Out:
# ['rt dineshdsouza: these #blacklivesmatter and #whitelivesmatter groups seem to have no idea how closely their principles mirror each other #…',
#  '#adee rt jen_i_yam: i beg to differ son!! but thanks so much for your input!! #blacklivesmatter is to blame for this rhetoric! …',
#  'rt mygianluca: rt breaking!  #blacklivesmatter attacks trumpsters in #virginia!  potus declare this soros-funded terrorist group, now!',
#  'rt namesnotbecky: the horror straight from the #unitetheright rally  just kidding. these are #blacklivesmatter "pr… https://t.co/shtpv5fk3u',
#  "if america is so racist and anti-black, what's the country that black people can't wait to get to? #blacklivesmatter https://t.co/foewlrbulw",
#  'must be the flags fault?  #takedowntheflag #blacklivesmatter  @mittromney @potus @deray @shaunking 1ofthesemustknow  https://t.co/39ghrdy1dz',
#  'lawless: poll worker wearing #blacklivesmatter gear at brooklyn polling station  https://t.co/newrl6ntyl https://t.co/nadpxnkhb5',
#  'las vegas strip murderer black w/ oregon plates. #blacklivesmatter silent https://t.co/9de0oaeol0 #tcot #tlot #tgdn https://t.co/oqxtmfb3d8',
#  'rt @gengspatton: why? in exchange for the fbi created #kwanzaa https://t.co/dbuzpidytv #blacklivesmatter @gengspatton #rebootliberty  https…',
#  'rt @berenabasg: make this viral!!  we need answers!! @sfpd  #blacklivesmatter #sfpd https://t.co/cqtzdcfu5z',
#  'rt @tharealversace: #blacklivesmatter',
#  'rt @jusscallmeg: bernie has acknowledged the fact that #blacklivesmatter and wants to tax the mega finance companies to fund free college e…',
#  'rt @dantejordanp: nought to do with me. #protestpoetry #blacklivesmatter #poetry #originalpoetry https://t.co/orwn6ec4yi',
#  'rt prisonplanet: another public relations disaster for #blacklivesmatter https://t.co/u7iopz7bex',
#  'rt foxnews: .diamondandsilk: "i didn\'t like the white nationalists... but i also didn\'t like #blacklivesmatter and… https://t.co/rg0ukfrxlu',
#  'rt i_amamerica: former president  barack hussein obama never condemned the terrorist organization blacklivesmatter.  yes, i said terrorist …',
#  'rt i_amamerica: i would like to see every member of the congressional black caucus denounce the terrorist organization blacklivesmatters an…',
#  'rt alwaysactions: 🚨 a great example of a #blm "peaceful protest"  #blacklivesmatter is a #terrorist group https://t.co/z3f3c3ckzq',
#  'rt iwillredpillyou: so... remember when baltimore #blacklivesmatter rioted and burnt the city down? it was totally… https://t.co/atkeukzink',
#  'rt i_amamerica: dear antifa and blacklivesmatters history does not come with an eraser. what next?  burning books?',
#  'rt stump4trumppac: #blacklivesmatter riot, burn down gas station as they repeatedly chant "black power"  will #fak… https://t.co/tnbnbo0onz',
#  'rt georgiadirtroad: #fakenews media was silent when obama refused to condemn #blacklivesmatter\xa0yet look how they t… https://t.co/7o8b68k14k',
#  'rt steve_janiszak: #charlottesville violence was caused by #antifa and #blacklivesmatter 👊👊👊👊👊👊👊👊#tcot #ccot https://t.co/qiswdknz79',
#  'rt iwillredpillyou: so... remember when baltimore #blacklivesmatter rioted and burnt the city down? it was totally… https://t.co/8v5j6pmz3m',
#  '#vegasgopdebate what about #blacklivesmatter problem? will anybody care about it?',
#  'rt _makada_: the white supremacists doing nazi salutes at #charlottesville and #blacklivesmatter black supremacists are two sides of the sa…',
#  'rt stockmonsterusa: watters: last month in minnesota at a #blacklivesmatter protest 21 police officers were injure… https://t.co/p7qh3ggiqj',
#  "it's the #blacklivesmatter olympics!! -cop killing -fence hurtling -trump voter assaulting -etc  #makeamericagreatagain ������ #tcot #ccot https://t.co/zojeaf5vpa",
#  '#blacklivesmatter supporter says: "we need to start killing people."  \'white people, give us your money &amp; house\'.  domestic terrorist. https://t.co/1pcjd2qjd8',
#  'what do #resistance anti-#trump group and #blacklivesmatter have in common❓#georgesoros  #maga #mypresidenttrump �� https://t.co/wwdtp8c0vk https://t.co/iadt72fy39',
#  '#democrat denial   #russianhacking  did not force #obama to conduct a #waronpolice  did not force #hillary to praise #blacklivesmatter https://t.co/ygb2bowxvm',
#  'in defense of the #blmkidnapping name, you can bet dollars to doughnuts that the kidnappers support #blacklivesmatter hateful rhetoric',
#  '#blacklivesmatter your candidate hillary uses the death of black people for political advantage! stay woke ! https://t.co/t4mjharxmg',
#  'https://t.co/8doqx3kc5j more proof #georgesoros behind #laraza #blacklivesmatter #msm and #hillaryclinton as his puppet. ✔save �� #votetrump',
#  'young black men are 7+x more likely to murder than young white men. let\'s pretend otherwise--and blame "racist" caps. #blacklivesmatter',
#  'this is brilliant. next time someone tells you "all lives matter," use the checklist below to qualify that statement. #blacklivesmatter https://t.co/oprpihqttl',
#  "'@mitchellvii #election2016 #blacklivesmatter #godblessamerica https://t.co/lhyzeuzjqd'",
#  'please retweet. thanks for the help. -vj #blacktwitter #blacklivesmatter #tcot https://t.co/ybo2o7ohkz',
#  'uh....obama had reps from domestic terrorist group #blacklivesmatter in the white house. https://t.co/z1iq1qbrlm',
#  'cult-like demands of blacklivesmatter have extended to @unh  time for higher education to grow a spine.  ✔️petition https://t.co/yyrtgj7fbx https://t.co/wulvny9ncw',
#  '#blacklivesmatter\xa0supporters plan looting sprees as hurricane matthew hits. just read their tweets�� #prayforflorida  https://t.co/whflrzz8l0 https://t.co/erkc7qoc5x',
#  '#blacklivesmatter supporters plan looting sprees as hurricane matthew hits. just read their tweets� #prayforflorida  https://t.co/gdkq6wfggu https://t.co/6gilj9rql3',
#  '#informyourvote2016 #blacklivesmatter #neverhillary #decision2016 #nevertrump #jillnothill #bernieorbust   �� i love ���������� this answer! https://t.co/m7nxx17ebu',
#  '#occupywallstreet  #blacklivesmatters  #nodapl  #stoptpp  #socialmedia successes congressional censorship is coming! https://t.co/t1jghei0eh',
#  '#blacklivesmatter activists literally making money off of white guilt. https://t.co/c5hzaz1qjw you have to admire their entrepreneurship.',
#  'police must stop killing black men or else! #freerevpinkney #blacklivesmatter https://t.co/m35gmrzo9p https://t.co/q9qzrrras5',
#  'taxpayers gave these kids a #free ed &amp; #blacklivesmatter is what they did w/ it? nothing free is appreciated https://t.co/nfgpwffev3',
#  '#boycottoldglory: they were selling the #blacklivesmatter shirts thru walmart.',
#  'even leftist daily news gets it @andieiamwhoiam @lewiswade35 civilized people tire of #blacklivesmatter terrorism  https://t.co/sfxvmbjvu9 …',
#  "keep it. i'm plenty happy with you amplifying the anti-racist message of #blacklivesmatter with your vitriol. @johnflanagan72"]

# %%
#look at tweets to see how the sentiment scores did on sarcasm
(right_troll_df[right_troll_df["content"].str.contains("thanks obama")][["content","Neutral_Score","Negative_Score","Positive_Score","Compound_Score"]]).head(5)
# Out:
#                                                   content Neutral_Score  \
# 35975   rt richardstiller4: polnewsforever ten_gop tha...          0.49
# 43986   new post: thanks obama! illegal alien satantis...         0.519
# 80656   it's cheap and easy to say, "thanks obama!" th...         0.757
# 93460   does it seem like everyone in the world wants ...         0.693
# 165041  isis celebrates victory in ramadi ➠ thanks oba...         0.488
#
#              Negative_Score       Positive_Score Compound_Score
# 35975                 0.307                0.203        -0.3595
# 43986   0.34600000000000003                0.135        -0.7712
# 80656                   0.0                0.243         0.7263
# 93460                 0.129  0.17800000000000002          0.128
# 165041                 0.19                0.322         0.4019

# %%
# x labels
right_sentiment = pd.DataFrame(final_df["Right_Sentiment"])
# left_sentiment = pd.DataFrame(final_df["Left_Sentiment"])
x_axis = np.arange(-1, 1, .1)
topic = pd.DataFrame(final_df["Topic"])

# y labels
y_axis_right = pd.DataFrame(final_df["Right_Updates"])
# y_axis_left = pd.DataFrame(final_df["Left_Updates"])

#circle labels
labels = final_df["Topic"]

# Build the scatter plots for each city type
ax1 = topic.plot(kind='scatter',x=right_sentiment, y=y_axis_right,
                       color="red", s=right_sentiment, label = "Right", 
                       alpha = 0.5, edgecolor = "black", linewidths = 1.5)    
# ax2 = topic.plot(kind='scatter', x=x_axis, y="0", 
#                           color="blue",s=final_df["Left_Sentiment"]*2, label = "Left Sentiment", 
#                           alpha = 0.5, edgecolor = "black", linewidths = 1.5, ax=ax1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-132-a610ef44863c> in <module>()
#      15 ax1 = topic.plot(kind='scatter',x=right_sentiment, y=y_axis_right,
#      16                        color="red", s=right_sentiment, label = "Right",
# ---> 17                        alpha = 0.5, edgecolor = "black", linewidths = 1.5)
#      18 # ax2 = topic.plot(kind='scatter', x=x_axis, y="0",
#      19 #                           color="blue",s=final_df["Left_Sentiment"]*2, label = "Left Sentiment",
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1975                  yerr=yerr, xerr=xerr,
#    1976                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1977                  **kwds)
#    1978
#    1979
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1741         if isinstance(data, ABCDataFrame):
#    1742             plot_obj = klass(data, x=x, y=y, subplots=subplots, ax=ax,
# -> 1743                              kind=kind, **kwds)
#    1744         else:
#    1745             raise ValueError("plot kind %r can only be used for data frames"
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __init__(self, data, x, y, s, c, **kwargs)
#     843             # the handling of this argument later
#     844             s = 20
# --> 845         super(ScatterPlot, self).__init__(data, x, y, s=s, **kwargs)
#     846         if is_integer(c) and not self.data.columns.holds_integer():
#     847             c = self.data.columns[c]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __init__(self, data, x, y, **kwargs)
#     817         if is_integer(y) and not self.data.columns.holds_integer():
#     818             y = self.data.columns[y]
# --> 819         if len(self.data[x]._get_numeric_data()) == 0:
#     820             raise ValueError(self._kind + ' requires x column to be numeric')
#     821         if len(self.data[y]._get_numeric_data()) == 0:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2679             return self._getitem_array(key)
#    2680         elif isinstance(key, DataFrame):
# -> 2681             return self._getitem_frame(key)
#    2682         elif is_mi_columns:
#    2683             return self._getitem_multilevel(key)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_frame(self, key)
#    2762     def _getitem_frame(self, key):
#    2763         if key.values.size and not is_bool_dtype(key.values):
# -> 2764             raise ValueError('Must pass DataFrame with boolean values only')
#    2765         return self.where(key)
#    2766
#
# ValueError: Must pass DataFrame with boolean values only

# %%
#find a better weay to plot. start again
ind = 1

def getXTextLocation(locations):
    lower = min(locations)
    higher = max(locations)
    return ((higher - lower)/2)+lower

fig,ax = plt.subplots(1)

for row in final_df.iterrows():
    row_data = row[1]
    ax.plot([row_data['Right_Sentiment'], row_data['Left_Sentiment']], [ind, ind], c='black')
    ax.scatter([row_data['Right_Sentiment'], row_data['Left_Sentiment']], [ind, ind], s=[row_data['Right_Frequency']/500, row_data['Left_Frequency']/500], c=['red', 'blue'])
    ax.text(getXTextLocation([row_data['Right_Sentiment'], row_data['Left_Sentiment']]), ind+.15, row_data['Topic'])
    ind += 1
plt.xlim(-1, 1) 
ax.get_yaxis().set_visible(False)
plt.show()
plt.savefig("Images/sentiment_leftandright_1.png")

# %%
#narrow in for better viewing of data
ind = 1

def getXTextLocation(locations):
    lower = min(locations)
    higher = max(locations)
    return ((higher - lower)/2)+lower

fig,ax = plt.subplots(1)

for row in final_df.iterrows():
    row_data = row[1]
    ax.plot([row_data['Right_Sentiment'], row_data['Left_Sentiment']], [ind, ind], c='black')
    ax.scatter([row_data['Right_Sentiment'], row_data['Left_Sentiment']], [ind, ind], s=[row_data['Right_Frequency']/500, row_data['Left_Frequency']/500], c=['red', 'blue'])
    ax.text(getXTextLocation([row_data['Right_Sentiment'], row_data['Left_Sentiment']]), ind+.2, row_data['Topic'])
    ind += 1
plt.xlim(-.25, .25) 
# ax.get_yaxis().set_visible(False)

# Incorporate the other graph properties
plt.title("Sentiment and Frequency of Most Used Words")
plt.xlabel("VADER Score")
plt.ylabel("Updates/Reactions")
# plt.legend(Right_Sentiment = "Right Troll Accounts")
labels = final_df["Topic"]

textstr = "Note: \nSize corresponds with the \namount of times the topic \nwas used in a tweet."
plt.text(.26,5,textstr, fontsize=11)

# show plot and save as a png
plt.show()
plt.savefig("Images/sentiment_leftandright_2.png")
